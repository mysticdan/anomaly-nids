# %% [markdown]
# # Dual-Stage LSTM-Autoencoder Feature Selection Comparison
#
# Memory-efficient CSE-CICIDS2018 experiment using four feature-selection methods, 80/20 benign-per-day temporal split, non-overlapping windows, and a residual dual-stage LSTM autoencoder.

# %%
import gc
import glob
import json
import os
import pickle
import shutil
import tempfile
import time
import warnings

import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.feature_selection import RFE, mutual_info_classif
from sklearn.metrics import (
    accuracy_score,
    auc,
    f1_score,
    precision_recall_curve,
    precision_score,
    recall_score,
    roc_auc_score,
)
from sklearn.preprocessing import StandardScaler
from mrmr import mrmr_classif

warnings.filterwarnings("ignore")
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")


def log_step(message):
    print(f"[{time.strftime('%H:%M:%S')}] {message}", flush=True)
# Out:
# Using device: cpu

# %%
# --- Configuration ---
DATASET_DIR = "/home/dhani/AnomalyIDS/dataset"
ARTIFACTS_DIR = "/home/dhani/AnomalyIDS/dual-stage-ae/artifacts"
TEMP_ROOT = "/tmp/dual_stage_ae"

TIME_STEPS = 10
WINDOW_STRIDE = TIME_STEPS  # non-overlapping windows
TRAIN_BENIGN_RATIO = 0.8
HIDDEN_DIM = 64
LEARNING_RATE = 0.001
DROPOUT = 0.2
BATCH_SIZE = 64
EPOCHS_STAGE1 = 3
EPOCHS_STAGE2 = 3
K_FEATURES = 10
CSV_CHUNK_SIZE = 50000
PARQUET_BATCH_SIZE = 32768
FS_SAMPLE_PER_CLASS = 20000
RFE_SAMPLE_PER_CLASS = 5000
RF_ESTIMATORS = 25
RFE_RF_ESTIMATORS = 10
RFE_STEP = 5
THRESHOLD_PERCENTILE = 95
CORRELATION_THRESHOLD = 0.9

# %%
def safe_name(name):
    return name.lower().replace(" ", "_").replace("-", "_")


def optimize_df(df):
    numeric_cols = [col for col in df.columns if col != "Label"]
    df[numeric_cols] = df[numeric_cols].astype("float32")
    return df


def get_shared_feature_columns(dataset_dir):
    log_step(f"Scanning shared feature columns: {dataset_dir}")
    csv_files = sorted(glob.glob(os.path.join(dataset_dir, "*.csv")))
    if not csv_files:
        raise ValueError("No CSV files found in dataset directory.")
    reference_columns = pd.read_csv(csv_files[0], nrows=0).columns.tolist()
    shared_columns = set(reference_columns)
    for file in csv_files[1:]:
        shared_columns &= set(pd.read_csv(file, nrows=0).columns.tolist())
    feature_columns = [
        col for col in reference_columns
        if col in shared_columns and col not in {"Label", "Timestamp"}
    ]
    if not feature_columns:
        raise ValueError("No shared feature columns were found.")
    log_step(f"Shared feature columns ready: {len(feature_columns)}")
    return feature_columns


def clean_chunk(df, feature_columns):
    cleaned = df[feature_columns + ["Label"]].copy()
    cleaned[feature_columns] = cleaned[feature_columns].apply(pd.to_numeric, errors="coerce")
    cleaned.replace([np.inf, -np.inf], np.nan, inplace=True)
    valid_mask = cleaned[feature_columns].notna().all(axis=1) & cleaned["Label"].notna()
    cleaned = cleaned.loc[valid_mask].copy()
    if cleaned.empty:
        return cleaned
    return optimize_df(cleaned)


def count_valid_benign_rows(file_path, feature_columns, chunk_size=CSV_CHUNK_SIZE):
    log_step(f"Counting valid benign rows: {os.path.basename(file_path)}")
    total = 0
    usecols = feature_columns + ["Label"]
    for chunk in pd.read_csv(file_path, usecols=usecols, chunksize=chunk_size, low_memory=False):
        chunk = clean_chunk(chunk, feature_columns)
        total += int((chunk["Label"] == "Benign").sum())
    log_step(f"Valid benign rows in {os.path.basename(file_path)}: {total}")
    return total


def update_sample_buffer(buffer_df, chunk_df, max_rows, rng):
    if chunk_df.empty:
        return buffer_df
    combined = chunk_df.copy() if buffer_df is None or buffer_df.empty else pd.concat([buffer_df, chunk_df], ignore_index=True)
    if len(combined) <= max_rows:
        return combined.reset_index(drop=True)
    sampled_idx = rng.choice(len(combined), size=max_rows, replace=False)
    return combined.iloc[sampled_idx].reset_index(drop=True)

# %%
def get_representative_sample(dataset_dir, sample_size_per_class=FS_SAMPLE_PER_CLASS, feature_columns=None):
    log_step("Sampling bounded data for feature selection")
    benign_sample = None
    attack_sample = None
    rng = np.random.default_rng(SEED)
    csv_files = sorted(glob.glob(os.path.join(dataset_dir, "*.csv")))
    if feature_columns is None:
        feature_columns = get_shared_feature_columns(dataset_dir)
    usecols = feature_columns + ["Label"]

    for file in csv_files:
        log_step(f"Sampling file: {os.path.basename(file)}")
        for chunk in pd.read_csv(file, usecols=usecols, chunksize=CSV_CHUNK_SIZE, low_memory=False):
            chunk = clean_chunk(chunk, feature_columns)
            if chunk.empty:
                continue
            benign_chunk = chunk[chunk["Label"] == "Benign"]
            attack_chunk = chunk[chunk["Label"] != "Benign"]
            benign_sample = update_sample_buffer(benign_sample, benign_chunk, sample_size_per_class, rng)
            attack_sample = update_sample_buffer(attack_sample, attack_chunk, sample_size_per_class, rng)
            del chunk, benign_chunk, attack_chunk
            gc.collect()

    sampled_frames = []
    if benign_sample is not None and not benign_sample.empty:
        sampled_frames.append(benign_sample)
    if attack_sample is not None and not attack_sample.empty:
        sampled_frames.append(attack_sample)
    if not sampled_frames:
        raise ValueError("No valid rows found for feature selection sampling.")

    combined = pd.concat(sampled_frames, ignore_index=True)
    X = combined[feature_columns].astype("float32")
    y = (combined["Label"] != "Benign").astype("int8").values
    log_step(f"Feature selection sample shape: {X.shape}")
    log_step(f"Shared feature columns: {len(feature_columns)}")
    if X.isna().any().any():
        raise ValueError("NaNs remain in feature selection sample.")
    return X, y


def get_balanced_subset(X, y, max_per_class):
    rng = np.random.default_rng(SEED)
    idx_parts = []
    for cls in [0, 1]:
        cls_idx = np.flatnonzero(y == cls)
        take = min(len(cls_idx), max_per_class)
        if take == 0:
            continue
        if len(cls_idx) > take:
            cls_idx = rng.choice(cls_idx, size=take, replace=False)
        idx_parts.append(cls_idx)
    if not idx_parts:
        raise ValueError("Balanced subset could not be created.")
    idx = np.concatenate(idx_parts)
    rng.shuffle(idx)
    return X.iloc[idx].reset_index(drop=True), y[idx]


def compute_mi_scores(X, y):
    return pd.Series(mutual_info_classif(X, y, random_state=SEED), index=X.columns, dtype="float64")


def prune_correlated_features(X, y, threshold=CORRELATION_THRESHOLD):
    log_step(f"Pruning correlated features at threshold={threshold}")
    mi_scores = compute_mi_scores(X, y)
    variances = X.var()
    corr_matrix = X.corr().abs()
    columns = X.columns.tolist()
    dropped = set()
    dropped_details = []

    for i, left_col in enumerate(columns):
        if left_col in dropped:
            continue
        for j in range(i + 1, len(columns)):
            right_col = columns[j]
            if right_col in dropped:
                continue
            corr_value = corr_matrix.loc[left_col, right_col]
            if pd.isna(corr_value) or corr_value <= threshold:
                continue
            left_mi, right_mi = float(mi_scores[left_col]), float(mi_scores[right_col])
            left_var, right_var = float(variances[left_col]), float(variances[right_col])
            if left_mi < right_mi:
                drop_col, keep_col = left_col, right_col
            elif right_mi < left_mi:
                drop_col, keep_col = right_col, left_col
            elif left_var < right_var:
                drop_col, keep_col = left_col, right_col
            elif right_var < left_var:
                drop_col, keep_col = right_col, left_col
            else:
                drop_col, keep_col = right_col, left_col
            dropped.add(drop_col)
            dropped_details.append({
                "kept_feature": keep_col,
                "dropped_feature": drop_col,
                "correlation": float(corr_value),
                "kept_mi": float(mi_scores[keep_col]),
                "dropped_mi": float(mi_scores[drop_col]),
                "kept_variance": float(variances[keep_col]),
                "dropped_variance": float(variances[drop_col]),
            })
            if drop_col == left_col:
                break

    pruned_columns = [col for col in columns if col not in dropped]
    log_step(f"Correlation pruning dropped {len(dropped_details)} features; {len(pruned_columns)} remain")
    return pruned_columns, dropped_details, mi_scores

# %%
def select_features_mi(X, y, k):
    log_step("Selecting features: Mutual Information")
    k = min(k, X.shape[1])
    mi_scores = compute_mi_scores(X, y)
    selected = X.columns[np.argsort(mi_scores.values)[-k:]].tolist()
    log_step(f"MI selected: {selected}")
    return selected


def select_features_rf(X, y, k):
    log_step("Selecting features: RF Importance")
    from sklearn.ensemble import RandomForestClassifier
    k = min(k, X.shape[1])
    rf = RandomForestClassifier(
        n_estimators=RF_ESTIMATORS,
        random_state=SEED,
        n_jobs=1,
        max_depth=12,
        min_samples_leaf=5,
    )
    rf.fit(X, y)
    selected = X.columns[np.argsort(rf.feature_importances_)[-k:]].tolist()
    log_step(f"RF selected: {selected}")
    return selected


def select_features_rfe(X, y, k):
    log_step("Selecting features: RFE")
    from sklearn.ensemble import RandomForestClassifier
    k = min(k, X.shape[1])
    X_small, y_small = get_balanced_subset(X, y, RFE_SAMPLE_PER_CLASS)
    log_step(f"RFE subset shape: {X_small.shape}")
    rf = RandomForestClassifier(
        n_estimators=RFE_RF_ESTIMATORS,
        random_state=SEED,
        n_jobs=1,
        max_depth=10,
        min_samples_leaf=10,
    )
    rfe = RFE(estimator=rf, n_features_to_select=k, step=RFE_STEP)
    rfe.fit(X_small, y_small)
    selected = X_small.columns[rfe.support_].tolist()
    log_step(f"RFE selected: {selected}")
    return selected


def mrmr_relevance_mi(X, y):
    return compute_mi_scores(X, np.asarray(y))


def select_features_mrmr(X, y, k):
    log_step("Selecting features: mRMR")
    k = min(k, X.shape[1])
    selected = mrmr_classif(
        X=X,
        y=pd.Series(y, name="Label"),
        K=k,
        relevance=mrmr_relevance_mi,
        redundancy="c",
        n_jobs=1,
        show_progress=False,
    )
    selected = list(selected)
    log_step(f"mRMR selected: {selected}")
    return selected


methods = {
    "Mutual Information": select_features_mi,
    "RF Importance": select_features_rf,
    "RFE": select_features_rfe,
    "mRMR": select_features_mrmr,
}

# %%
def write_parquet_chunk(writer, df, path):
    if df.empty:
        return writer
    table = pa.Table.from_pandas(df, preserve_index=False)
    if writer is None:
        writer = pq.ParquetWriter(path, table.schema, compression="snappy")
    writer.write_table(table)
    return writer


def preprocess_and_save_parquet(dataset_dir, selected_features, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    csv_files = sorted(glob.glob(os.path.join(dataset_dir, "*.csv")))
    parquet_files = {"train": [], "test": []}
    split_audit = []
    cols_to_keep = selected_features + ["Label"]

    log_step(f"Preprocessing 80/20 benign split to {output_dir}")
    for file in csv_files:
        fname = os.path.basename(file)
        log_step(f"Preprocessing file: {fname}")
        train_path = os.path.join(output_dir, f"train_{fname}.parquet")
        test_path = os.path.join(output_dir, f"test_{fname}.parquet")
        total_benign = count_valid_benign_rows(file, selected_features)
        train_cap = int(total_benign * TRAIN_BENIGN_RATIO)
        benign_seen = 0
        train_benign = 0
        test_benign = 0
        attack_test = 0
        train_writer = None
        test_writer = None

        for chunk in pd.read_csv(file, usecols=cols_to_keep, chunksize=CSV_CHUNK_SIZE, low_memory=False):
            chunk = clean_chunk(chunk, selected_features)
            if chunk.empty:
                continue
            chunk = chunk[cols_to_keep]
            benign = chunk[chunk["Label"] == "Benign"]
            attack = chunk[chunk["Label"] != "Benign"]

            if not benign.empty:
                can_take = max(0, train_cap - benign_seen)
                take_train = min(len(benign), can_take)
                if take_train > 0:
                    train_writer = write_parquet_chunk(train_writer, benign.iloc[:take_train], train_path)
                test_benign_part = benign.iloc[take_train:]
                benign_seen += len(benign)
                train_benign += take_train
                test_benign += len(test_benign_part)
            else:
                test_benign_part = benign

            if not attack.empty:
                attack_test += len(attack)

            test_part = pd.concat([test_benign_part, attack], axis=0).sort_index()
            if not test_part.empty:
                test_writer = write_parquet_chunk(test_writer, test_part, test_path)

            del chunk, benign, attack, test_benign_part, test_part
            gc.collect()

        if train_writer is not None:
            train_writer.close()
        else:
            pd.DataFrame(columns=cols_to_keep).to_parquet(train_path, index=False)
        if test_writer is not None:
            test_writer.close()
        else:
            pd.DataFrame(columns=cols_to_keep).to_parquet(test_path, index=False)

        parquet_files["train"].append(train_path)
        parquet_files["test"].append(test_path)
        split_audit.append({
            "file": fname,
            "total_valid_benign": int(total_benign),
            "train_benign": int(train_benign),
            "test_benign": int(test_benign),
            "attack_test": int(attack_test),
            "train_benign_ratio": float(train_benign / total_benign) if total_benign else 0.0,
        })
        log_step(f"Done {fname}: train_benign={train_benign}, test_benign={test_benign}, attack_test={attack_test}")
        gc.collect()

    return parquet_files, pd.DataFrame(split_audit)


def fit_streaming_scaler(file_list, selected_features):
    log_step("Fitting streaming StandardScaler")
    scaler = StandardScaler()
    seen_batch = False
    for file in file_list:
        log_step(f"Scaler file: {os.path.basename(file)}")
        parquet_file = pq.ParquetFile(file)
        for batch in parquet_file.iter_batches(batch_size=PARQUET_BATCH_SIZE, columns=selected_features):
            df = batch.to_pandas()
            if df.empty:
                continue
            scaler.partial_fit(df[selected_features].to_numpy(dtype=np.float32, copy=True))
            seen_batch = True
            del df
    if not seen_batch:
        raise ValueError("No train data available to fit StandardScaler.")
    log_step("Scaler ready")
    return scaler


def count_window_sequences(n_rows, time_steps=TIME_STEPS, stride=WINDOW_STRIDE):
    if n_rows < time_steps:
        return 0
    return 1 + (n_rows - time_steps) // stride


def count_sequences_from_parquet(file_list, time_steps=TIME_STEPS, stride=WINDOW_STRIDE):
    total = 0
    for file in file_list:
        total += count_window_sequences(pq.ParquetFile(file).metadata.num_rows, time_steps, stride)
    return total

# %%
class StreamingLSTMDataset(torch.utils.data.IterableDataset):
    def __init__(self, file_list, selected_features, time_steps, stride=1, scaler=None, is_test=False):
        super().__init__()
        self.file_list = file_list
        self.selected_features = selected_features
        self.time_steps = time_steps
        self.stride = stride
        self.scaler = scaler
        self.is_test = is_test

    def __iter__(self):
        for file in self.file_list:
            parquet_file = pq.ParquetFile(file)
            buffer = None
            labels_buffer = None

            for batch in parquet_file.iter_batches(batch_size=PARQUET_BATCH_SIZE, columns=self.selected_features + ["Label"]):
                df = batch.to_pandas()
                if df.empty:
                    continue
                data_vals = df[self.selected_features].to_numpy(dtype=np.float32, copy=True)
                if self.scaler is not None:
                    data_vals = self.scaler.transform(data_vals).astype(np.float32)
                labels = (df["Label"] != "Benign").astype(np.int8).values if self.is_test else None

                if buffer is not None and len(buffer) > 0:
                    data_vals = np.concatenate([buffer, data_vals], axis=0)
                    if self.is_test:
                        labels = np.concatenate([labels_buffer, labels])

                limit = len(data_vals) - self.time_steps + 1
                if limit > 0:
                    for i in range(0, limit, self.stride):
                        seq = data_vals[i : i + self.time_steps]
                        if self.is_test:
                            label = 1 if labels[i : i + self.time_steps].sum() > 0 else 0
                            yield torch.from_numpy(seq), torch.tensor(label, dtype=torch.long)
                        else:
                            yield torch.from_numpy(seq), torch.from_numpy(seq)
                    next_start = ((limit - 1) // self.stride + 1) * self.stride
                else:
                    next_start = 0

                if next_start < len(data_vals):
                    buffer = data_vals[next_start:].copy()
                    labels_buffer = labels[next_start:].copy() if self.is_test else None
                else:
                    buffer = None
                    labels_buffer = None

                del df, data_vals, labels

            del buffer, labels_buffer
            gc.collect()

# %%
class LSTMAutoencoder(nn.Module):
    def __init__(self, num_features, time_steps, hidden_dim=64, dropout=0.2):
        super().__init__()
        self.time_steps = time_steps
        self.encoder_lstm = nn.LSTM(num_features, hidden_dim, batch_first=True)
        self.encoder_dropout = nn.Dropout(dropout)
        self.decoder_lstm = nn.LSTM(hidden_dim, hidden_dim, batch_first=True)
        self.decoder_dropout = nn.Dropout(dropout)
        self.output_layer = nn.Linear(hidden_dim, num_features)

    def forward(self, x):
        _, (hn, _) = self.encoder_lstm(x)
        latent = self.encoder_dropout(hn[-1])
        repeated = latent.unsqueeze(1).repeat(1, self.time_steps, 1)
        decoded, _ = self.decoder_lstm(repeated)
        decoded = self.decoder_dropout(decoded)
        return self.output_layer(decoded)


class DualStageAutoencoder(nn.Module):
    def __init__(self, num_features, time_steps, hidden_dim=64, dropout=0.2):
        super().__init__()
        self.stage1 = LSTMAutoencoder(num_features, time_steps, hidden_dim, dropout)
        self.stage2 = LSTMAutoencoder(num_features, time_steps, hidden_dim, dropout)

    def forward(self, x):
        recon1 = self.stage1(x)
        residual = torch.abs(x - recon1)
        recon_residual = self.stage2(residual)
        return recon1, recon_residual


def dual_stage_score(model, x):
    recon1, recon_residual = model(x)
    residual = torch.abs(x - recon1)
    stage1_error = residual.mean(dim=(1, 2))
    stage2_error = torch.abs(residual - recon_residual).mean(dim=(1, 2))
    return stage1_error + stage2_error

# %%
def train_stage1(model, parquet_files, selected_features, scaler):
    log_step("Training Stage 1 autoencoder")
    criterion = nn.L1Loss()
    optimizer = torch.optim.Adam(model.stage1.parameters(), lr=LEARNING_RATE)
    for epoch in range(1, EPOCHS_STAGE1 + 1):
        model.stage1.train()
        epoch_loss = 0.0
        total = 0
        dataset = StreamingLSTMDataset(parquet_files["train"], selected_features, TIME_STEPS, WINDOW_STRIDE, scaler=scaler)
        loader = DataLoader(dataset, batch_size=BATCH_SIZE)
        for bx, by in loader:
            bx, by = bx.to(device), by.to(device)
            optimizer.zero_grad()
            recon = model.stage1(bx)
            loss = criterion(recon, by)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * bx.size(0)
            total += bx.size(0)
        if total == 0:
            raise ValueError("No train sequences generated for stage 1.")
        log_step(f"Stage 1 epoch {epoch}/{EPOCHS_STAGE1} | loss={epoch_loss / total:.6f}")


def train_stage2(model, parquet_files, selected_features, scaler):
    log_step("Training Stage 2 residual autoencoder")
    for param in model.stage1.parameters():
        param.requires_grad = False
    model.stage1.eval()
    criterion = nn.L1Loss()
    optimizer = torch.optim.Adam(model.stage2.parameters(), lr=LEARNING_RATE)
    for epoch in range(1, EPOCHS_STAGE2 + 1):
        model.stage2.train()
        epoch_loss = 0.0
        total = 0
        dataset = StreamingLSTMDataset(parquet_files["train"], selected_features, TIME_STEPS, WINDOW_STRIDE, scaler=scaler)
        loader = DataLoader(dataset, batch_size=BATCH_SIZE)
        for bx, _ in loader:
            bx = bx.to(device)
            with torch.no_grad():
                residual = torch.abs(bx - model.stage1(bx))
            optimizer.zero_grad()
            recon_residual = model.stage2(residual)
            loss = criterion(recon_residual, residual)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * bx.size(0)
            total += bx.size(0)
        if total == 0:
            raise ValueError("No train sequences generated for stage 2.")
        log_step(f"Stage 2 epoch {epoch}/{EPOCHS_STAGE2} | loss={epoch_loss / total:.6f}")


def write_scores(model, file_list, selected_features, scaler, errors_path, labels_path=None):
    log_step(f"Scoring {'test' if labels_path is not None else 'train'} sequences")
    is_test = labels_path is not None
    total_sequences = count_sequences_from_parquet(file_list, TIME_STEPS, WINDOW_STRIDE)
    if total_sequences == 0:
        raise ValueError("No sequences generated for scoring.")
    log_step(f"Total sequences to score: {total_sequences}")
    errors = np.memmap(errors_path, dtype="float32", mode="w+", shape=(total_sequences,))
    labels = np.memmap(labels_path, dtype="int8", mode="w+", shape=(total_sequences,)) if is_test else None
    idx = 0
    model.eval()
    with torch.no_grad():
        dataset = StreamingLSTMDataset(file_list, selected_features, TIME_STEPS, WINDOW_STRIDE, scaler=scaler, is_test=is_test)
        loader = DataLoader(dataset, batch_size=BATCH_SIZE)
        for bx, by in loader:
            bx = bx.to(device)
            score = dual_stage_score(model, bx).cpu().numpy()
            end = idx + len(score)
            errors[idx:end] = score
            if is_test:
                labels[idx:end] = by.numpy()
            idx = end
    errors.flush()
    log_step("Scoring done")
    if is_test:
        labels.flush()
        return errors, labels
    return errors


def safe_roc_auc(y_true, scores):
    return float(roc_auc_score(y_true, scores)) if len(np.unique(y_true)) > 1 else float("nan")


def safe_pr_auc(y_true, scores):
    if len(np.unique(y_true)) < 2:
        return float("nan")
    precision, recall, _ = precision_recall_curve(y_true, scores)
    return float(auc(recall, precision))

# %%
def train_and_evaluate(method_name, selected_features, dataset_dir, pruned_feature_columns=None, dropped_correlated_features=None):
    print()
    log_step(f">>> Starting dual-stage pipeline for: {method_name}")
    pruned_feature_columns = pruned_feature_columns or selected_features
    dropped_correlated_features = dropped_correlated_features or []
    run_name = safe_name(method_name)
    os.makedirs(TEMP_ROOT, exist_ok=True)
    output_dir = tempfile.mkdtemp(prefix=f"{run_name}_", dir=TEMP_ROOT)
    artifact_dir = os.path.join(ARTIFACTS_DIR, run_name)
    os.makedirs(artifact_dir, exist_ok=True)

    parquet_files, split_audit_df = preprocess_and_save_parquet(dataset_dir, selected_features, output_dir)
    log_step("Split audit")
    print(split_audit_df.to_string(index=False))
    scaler = fit_streaming_scaler(parquet_files["train"], selected_features)

    log_step("Building dual-stage model")
    model = DualStageAutoencoder(len(selected_features), TIME_STEPS, HIDDEN_DIM, DROPOUT).to(device)
    train_stage1(model, parquet_files, selected_features, scaler)
    train_stage2(model, parquet_files, selected_features, scaler)

    train_errors_path = os.path.join(output_dir, f"train_errors_{run_name}.bin")
    train_errors = write_scores(model, parquet_files["train"], selected_features, scaler, train_errors_path)
    threshold = float(np.percentile(train_errors, THRESHOLD_PERCENTILE))
    log_step(f"Train anomaly threshold (P{THRESHOLD_PERCENTILE}): {threshold:.6f}")

    test_errors_path = os.path.join(output_dir, f"test_errors_{run_name}.bin")
    test_labels_path = os.path.join(output_dir, f"test_labels_{run_name}.bin")
    test_errors, test_labels = write_scores(model, parquet_files["test"], selected_features, scaler, test_errors_path, test_labels_path)

    y_true = np.asarray(test_labels)
    scores = np.asarray(test_errors)
    y_pred = (scores > threshold).astype(np.int8)
    log_step("Computing metrics")
    metrics = {
        "Selected Features": ", ".join(selected_features),
        "Accuracy": float(accuracy_score(y_true, y_pred)),
        "Precision": float(precision_score(y_true, y_pred, zero_division=0)),
        "Recall": float(recall_score(y_true, y_pred, zero_division=0)),
        "F1": float(f1_score(y_true, y_pred, zero_division=0)),
        "ROC-AUC": safe_roc_auc(y_true, scores),
        "PR-AUC": safe_pr_auc(y_true, scores),
    }

    model_path = os.path.join(artifact_dir, "model.pt")
    scaler_path = os.path.join(artifact_dir, "scaler.pkl")
    metadata_path = os.path.join(artifact_dir, "metadata.json")
    log_step("Saving artifacts")
    torch.save({
        "model_state_dict": model.state_dict(),
        "selected_features": selected_features,
        "threshold": threshold,
        "time_steps": TIME_STEPS,
        "window_stride": WINDOW_STRIDE,
        "hidden_dim": HIDDEN_DIM,
        "dropout": DROPOUT,
    }, model_path)
    with open(scaler_path, "wb") as f:
        pickle.dump(scaler, f)
    with open(metadata_path, "w") as f:
        json.dump({
            "method_name": method_name,
            "selected_features": selected_features,
            "pruned_feature_columns": pruned_feature_columns,
            "dropped_correlated_features": dropped_correlated_features,
            "train_benign_ratio": TRAIN_BENIGN_RATIO,
            "window_stride": WINDOW_STRIDE,
            "threshold": threshold,
            "threshold_percentile": THRESHOLD_PERCENTILE,
            "time_steps": TIME_STEPS,
            "hidden_dim": HIDDEN_DIM,
            "dropout": DROPOUT,
            "batch_size": BATCH_SIZE,
            "epochs_stage1": EPOCHS_STAGE1,
            "epochs_stage2": EPOCHS_STAGE2,
            "k_features": K_FEATURES,
            "split_audit": split_audit_df.to_dict(orient="records"),
            "metrics": metrics,
        }, f, indent=2)
    log_step(f"Saved model to {model_path}")
    log_step(f"Saved scaler to {scaler_path}")

    del train_errors, test_errors, test_labels, y_true, scores, y_pred, model
    gc.collect()
    shutil.rmtree(output_dir, ignore_errors=True)
    log_step(f"Finished method: {method_name}")
    return metrics

# %%
# --- Self-checks ---
def run_self_checks():
    with tempfile.TemporaryDirectory() as tmpdir:
        data = pd.DataFrame({
            "f1": np.arange(13, dtype=np.float32),
            "f2": np.arange(13, dtype=np.float32) * 2,
            "Label": ["Benign"] * 10 + ["Attack"] * 3,
        })
        data.to_csv(os.path.join(tmpdir, "toy.csv"), index=False)
        outdir = os.path.join(tmpdir, "parquet")
        parquet_files, audit = preprocess_and_save_parquet(tmpdir, ["f1", "f2"], outdir)
        row = audit.iloc[0]
        assert row["train_benign"] == 8
        assert row["test_benign"] == 2
        assert row["attack_test"] == 3
        train_ds = StreamingLSTMDataset(parquet_files["train"], ["f1", "f2"], time_steps=4, stride=4)
        test_ds = StreamingLSTMDataset(parquet_files["test"], ["f1", "f2"], time_steps=4, stride=4, is_test=True)
        assert sum(1 for _ in train_ds) == 2
        test_items = list(test_ds)
        assert len(test_items) == 1
        assert int(test_items[0][1]) == 1

    assert count_window_sequences(12, time_steps=10, stride=10) == 1
    assert count_window_sequences(20, time_steps=10, stride=10) == 2
    dummy_model = DualStageAutoencoder(K_FEATURES, TIME_STEPS, HIDDEN_DIM, DROPOUT)
    dummy_x = torch.randn(2, TIME_STEPS, K_FEATURES)
    recon1, recon2 = dummy_model(dummy_x)
    assert recon1.shape == dummy_x.shape
    assert recon2.shape == dummy_x.shape
    log_step("Self-checks passed")


run_self_checks()
# Out:
# [21:00:40] Preprocessing 80/20 benign split to /tmp/tmpq4_t1yyi/parquet
# [21:00:40] Preprocessing file: toy.csv
# [21:00:40] Counting valid benign rows: toy.csv
# [21:00:40] Valid benign rows in toy.csv: 10
# [21:00:40] Done toy.csv: train_benign=8, test_benign=2, attack_test=3
# [21:00:41] Self-checks passed

# %%
# --- Execution Loop ---
log_step("Starting full dual-stage comparison")
os.makedirs(ARTIFACTS_DIR, exist_ok=True)
shared_feature_columns = get_shared_feature_columns(DATASET_DIR)
log_step(f"Using {len(shared_feature_columns)} shared feature columns across all files")

X_fs, y_fs = get_representative_sample(
    DATASET_DIR,
    sample_size_per_class=FS_SAMPLE_PER_CLASS,
    feature_columns=shared_feature_columns,
)
pruned_feature_columns, dropped_correlated_features, pruning_mi_scores = prune_correlated_features(
    X_fs,
    y_fs,
    threshold=CORRELATION_THRESHOLD,
)
X_fs_pruned = X_fs[pruned_feature_columns].copy()
final_results = {}

for name, func in methods.items():
    selected_features = func(X_fs_pruned, y_fs, K_FEATURES)
    log_step(f"{name} selected features: {selected_features}")
    final_results[name] = train_and_evaluate(
        name,
        selected_features,
        DATASET_DIR,
        pruned_feature_columns=pruned_feature_columns,
        dropped_correlated_features=dropped_correlated_features,
    )
    gc.collect()

results_df = pd.DataFrame(final_results).T
print()
log_step("=== FINAL DUAL-STAGE COMPARISON ===")
print(results_df)
# Out:
# [21:00:41] Starting full dual-stage comparison
# [21:00:41] Scanning shared feature columns: /home/dhani/AnomalyIDS/dataset
# [21:00:41] Shared feature columns ready: 78
# [21:00:41] Using 78 shared feature columns across all files
# [21:00:41] Sampling bounded data for feature selection
# [21:00:41] Sampling file: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# [21:01:01] Sampling file: Friday-16-02-2018_TrafficForML_CICFlowMeter.csv
# [21:01:20] Sampling file: Friday-23-02-2018_TrafficForML_CICFlowMeter.csv
# [21:01:37] Sampling file: Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv
# [21:03:57] Sampling file: Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv
# [21:04:09] Sampling file: Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv
# [21:04:26] Sampling file: Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv
# [21:04:43] Sampling file: Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv
# [21:04:59] Sampling file: Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv
# [21:05:15] Sampling file: Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv
# [21:05:49] Feature selection sample shape: (40000, 78)
# [21:05:49] Shared feature columns: 78
# [21:05:49] Pruning correlated features at threshold=0.9
# [21:06:01] Correlation pruning dropped 36 features; 42 remain
# [21:06:01] Selecting features: Mutual Information
# [21:06:06] MI selected: ['Pkt Len Mean', 'Fwd Seg Size Min', 'Flow IAT Max', 'Fwd Pkts/s', 'Flow IAT Mean', 'Fwd Header Len', 'Flow Duration', 'Bwd Pkts/s', 'Init Fwd Win Byts', 'Dst Port']
# [21:06:06] Mutual Information selected features: ['Pkt Len Mean', 'Fwd Seg Size Min', 'Flow IAT Max', 'Fwd Pkts/s', 'Flow IAT Mean', 'Fwd Header Len', 'Flow Duration', 'Bwd Pkts/s', 'Init Fwd Win Byts', 'Dst Port']
#
# [21:06:06] >>> Starting dual-stage pipeline for: Mutual Information
# [21:06:06] Preprocessing 80/20 benign split to /tmp/dual_stage_ae/mutual_information_vy9or4s0
# [21:06:06] Preprocessing file: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# [21:06:06] Counting valid benign rows: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# [21:06:10] Valid benign rows in Friday-02-03-2018_TrafficForML_CICFlowMeter.csv: 762384
# [21:06:18] Done Friday-02-03-2018_TrafficForML_CICFlowMeter.csv: train_benign=609907, test_benign=152477, attack_test=286191
# [21:06:18] Preprocessing file: Friday-16-02-2018_TrafficForML_CICFlowMeter.csv
# [21:06:18] Counting valid benign rows: Friday-16-02-2018_TrafficForML_CICFlowMeter.csv
# [21:06:22] Valid benign rows in Friday-16-02-2018_TrafficForML_CICFlowMeter.csv: 446772
# [21:06:29] Done Friday-16-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=357417, test_benign=89355, attack_test=601802
# [21:06:29] Preprocessing file: Friday-23-02-2018_TrafficForML_CICFlowMeter.csv
# [21:06:29] Counting valid benign rows: Friday-23-02-2018_TrafficForML_CICFlowMeter.csv
# [21:06:33] Valid benign rows in Friday-23-02-2018_TrafficForML_CICFlowMeter.csv: 1048009
# [21:06:40] Done Friday-23-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=838407, test_benign=209602, attack_test=566
# [21:06:40] Preprocessing file: Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv
# [21:06:40] Counting valid benign rows: Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv
# [21:07:26] Valid benign rows in Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv: 7372557
# [21:08:36] Done Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=5898045, test_benign=1474512, attack_test=576191
# [21:08:37] Preprocessing file: Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv
# [21:08:37] Counting valid benign rows: Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv
# [21:08:39] Valid benign rows in Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv: 238037
# [21:08:41] Done Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv: train_benign=190429, test_benign=47608, attack_test=93063
# [21:08:41] Preprocessing file: Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv
# [21:08:41] Counting valid benign rows: Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv
# [21:08:45] Valid benign rows in Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv: 996077
# [21:08:52] Done Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=796861, test_benign=199216, attack_test=52498
# [21:08:52] Preprocessing file: Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv
# [21:08:52] Counting valid benign rows: Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv
# [21:08:56] Valid benign rows in Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv: 1048213
# [21:09:03] Done Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=838570, test_benign=209643, attack_test=362
# [21:09:03] Preprocessing file: Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv
# [21:09:03] Counting valid benign rows: Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv
# [21:09:06] Valid benign rows in Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv: 667626
# [21:09:13] Done Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=534100, test_benign=133526, attack_test=380949
# [21:09:13] Preprocessing file: Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv
# [21:09:13] Counting valid benign rows: Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv
# [21:09:16] Valid benign rows in Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv: 360833
# [21:09:24] Done Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=288666, test_benign=72167, attack_test=687742
# [21:09:24] Preprocessing file: Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv
# [21:09:24] Counting valid benign rows: Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv
# [21:09:30] Valid benign rows in Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv: 544200
# [21:09:37] Done Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=435360, test_benign=108840, attack_test=68871
# [21:09:38] Split audit
#                                               file  total_valid_benign  train_benign  test_benign  attack_test  train_benign_ratio
#    Friday-02-03-2018_TrafficForML_CICFlowMeter.csv              762384        609907       152477       286191            0.800000
#    Friday-16-02-2018_TrafficForML_CICFlowMeter.csv              446772        357417        89355       601802            0.799999
#    Friday-23-02-2018_TrafficForML_CICFlowMeter.csv             1048009        838407       209602          566            0.800000
#  Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv             7372557       5898045      1474512       576191            0.800000
#  Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv              238037        190429        47608        93063            0.799997
#  Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv              996077        796861       199216        52498            0.799999
#  Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv             1048213        838570       209643          362            0.800000
# Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv              667626        534100       133526       380949            0.799999
# Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv              360833        288666        72167       687742            0.799999
# Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv              544200        435360       108840        68871            0.800000
# [21:09:38] Fitting streaming StandardScaler
# [21:09:38] Scaler file: train_Friday-02-03-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:38] Scaler file: train_Friday-16-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:38] Scaler file: train_Friday-23-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:38] Scaler file: train_Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:39] Scaler file: train_Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:39] Scaler file: train_Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:39] Scaler file: train_Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:39] Scaler file: train_Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:39] Scaler file: train_Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:39] Scaler file: train_Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:09:39] Scaler ready
# [21:09:39] Building dual-stage model
# [21:09:39] Training Stage 1 autoencoder
# [21:11:45] Stage 1 epoch 1/3 | loss=0.155725
# [21:13:50] Stage 1 epoch 2/3 | loss=0.103486
# [21:17:52] Stage 1 epoch 3/3 | loss=0.091758
# [21:17:52] Training Stage 2 residual autoencoder
# [21:20:53] Stage 2 epoch 1/3 | loss=0.058654
# [21:23:51] Stage 2 epoch 2/3 | loss=0.049730
# [21:26:51] Stage 2 epoch 3/3 | loss=0.045474
# [21:26:51] Scoring train sequences
# [21:26:51] Total sequences to score: 1078772
# [21:28:22] Scoring done
# [21:28:22] Train anomaly threshold (P95): 0.549092
# [21:28:22] Scoring test sequences
# [21:28:22] Total sequences to score: 544513
# [21:29:12] Scoring done
# [21:29:12] Computing metrics
# [21:29:13] Saving artifacts
# [21:29:13] Saved model to /home/dhani/AnomalyIDS/dual-stage-ae/artifacts/mutual_information/model.pt
# [21:29:13] Saved scaler to /home/dhani/AnomalyIDS/dual-stage-ae/artifacts/mutual_information/scaler.pkl
# [21:29:13] Finished method: Mutual Information
# [21:29:13] Selecting features: RF Importance
# [21:29:14] RF selected: ['Flow Byts/s', 'Init Bwd Win Byts', 'Flow IAT Mean', 'Fwd Pkts/s', 'Fwd Seg Size Min', 'Flow IAT Max', 'Dst Port', 'Init Fwd Win Byts', 'Flow Duration', 'Bwd Pkts/s']
# [21:29:14] RF Importance selected features: ['Flow Byts/s', 'Init Bwd Win Byts', 'Flow IAT Mean', 'Fwd Pkts/s', 'Fwd Seg Size Min', 'Flow IAT Max', 'Dst Port', 'Init Fwd Win Byts', 'Flow Duration', 'Bwd Pkts/s']
#
# [21:29:14] >>> Starting dual-stage pipeline for: RF Importance
# [21:29:14] Preprocessing 80/20 benign split to /tmp/dual_stage_ae/rf_importance_huyz8ahu
# [21:29:14] Preprocessing file: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# [21:29:14] Counting valid benign rows: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# [21:29:19] Valid benign rows in Friday-02-03-2018_TrafficForML_CICFlowMeter.csv: 758334
# [21:29:28] Done Friday-02-03-2018_TrafficForML_CICFlowMeter.csv: train_benign=606667, test_benign=151667, attack_test=286191
# [21:29:29] Preprocessing file: Friday-16-02-2018_TrafficForML_CICFlowMeter.csv
# [21:29:29] Counting valid benign rows: Friday-16-02-2018_TrafficForML_CICFlowMeter.csv
# [21:29:33] Valid benign rows in Friday-16-02-2018_TrafficForML_CICFlowMeter.csv: 446772
# [21:29:42] Done Friday-16-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=357417, test_benign=89355, attack_test=601802
# [21:29:42] Preprocessing file: Friday-23-02-2018_TrafficForML_CICFlowMeter.csv
# [21:29:42] Counting valid benign rows: Friday-23-02-2018_TrafficForML_CICFlowMeter.csv
# [21:29:47] Valid benign rows in Friday-23-02-2018_TrafficForML_CICFlowMeter.csv: 1042301
# [21:29:55] Done Friday-23-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=833840, test_benign=208461, attack_test=566
# [21:29:55] Preprocessing file: Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv
# [21:29:55] Counting valid benign rows: Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv
# [21:30:47] Valid benign rows in Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv: 7313104
# [21:32:12] Done Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=5850483, test_benign=1462621, attack_test=576191
# [21:32:12] Preprocessing file: Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv
# [21:32:12] Counting valid benign rows: Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv
# [21:32:15] Valid benign rows in Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv: 235778
# [21:32:18] Done Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv: train_benign=188622, test_benign=47156, attack_test=92403
# [21:32:18] Preprocessing file: Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv
# [21:32:18] Counting valid benign rows: Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv
# [21:32:24] Valid benign rows in Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv: 988050
# [21:32:34] Done Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=790440, test_benign=197610, attack_test=52498
# [21:32:34] Preprocessing file: Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv
# [21:32:34] Counting valid benign rows: Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv
# [21:32:38] Valid benign rows in Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv: 1042603
# [21:32:48] Done Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=834082, test_benign=208521, attack_test=362
# [21:32:48] Preprocessing file: Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv
# [21:32:48] Counting valid benign rows: Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv
# [21:32:52] Valid benign rows in Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv: 663808
# [21:33:01] Done Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=531046, test_benign=132762, attack_test=380943
# [21:33:02] Preprocessing file: Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv
# [21:33:02] Counting valid benign rows: Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv
# [21:33:05] Valid benign rows in Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv: 360833
# [21:33:14] Done Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=288666, test_benign=72167, attack_test=687742
# [21:33:14] Preprocessing file: Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv
# [21:33:14] Counting valid benign rows: Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv
# [21:33:21] Valid benign rows in Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv: 538666
# [21:33:30] Done Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=430932, test_benign=107734, attack_test=68236
# [21:33:31] Split audit
#                                               file  total_valid_benign  train_benign  test_benign  attack_test  train_benign_ratio
#    Friday-02-03-2018_TrafficForML_CICFlowMeter.csv              758334        606667       151667       286191            0.800000
#    Friday-16-02-2018_TrafficForML_CICFlowMeter.csv              446772        357417        89355       601802            0.799999
#    Friday-23-02-2018_TrafficForML_CICFlowMeter.csv             1042301        833840       208461          566            0.799999
#  Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv             7313104       5850483      1462621       576191            0.800000
#  Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv              235778        188622        47156        92403            0.799998
#  Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv              988050        790440       197610        52498            0.800000
#  Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv             1042603        834082       208521          362            0.800000
# Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv              663808        531046       132762       380943            0.799999
# Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv              360833        288666        72167       687742            0.799999
# Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv              538666        430932       107734        68236            0.799999
# [21:33:31] Fitting streaming StandardScaler
# [21:33:31] Scaler file: train_Friday-02-03-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:31] Scaler file: train_Friday-16-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:31] Scaler file: train_Friday-23-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:31] Scaler file: train_Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:32] Scaler file: train_Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:32] Scaler file: train_Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:32] Scaler file: train_Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:32] Scaler file: train_Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:32] Scaler file: train_Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:32] Scaler file: train_Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:33:32] Scaler ready
# [21:33:32] Building dual-stage model
# [21:33:32] Training Stage 1 autoencoder
# [21:35:51] Stage 1 epoch 1/3 | loss=0.152122
# [21:38:09] Stage 1 epoch 2/3 | loss=0.110809
# [21:40:28] Stage 1 epoch 3/3 | loss=0.092953
# [21:40:28] Training Stage 2 residual autoencoder
# [21:43:26] Stage 2 epoch 1/3 | loss=0.063578
# [21:46:22] Stage 2 epoch 2/3 | loss=0.049840
# [21:49:18] Stage 2 epoch 3/3 | loss=0.046159
# [21:49:18] Scoring train sequences
# [21:49:18] Total sequences to score: 1071216
# [21:50:47] Scoring done
# [21:50:47] Train anomaly threshold (P95): 0.513431
# [21:50:47] Scoring test sequences
# [21:50:47] Total sequences to score: 542493
# [21:51:36] Scoring done
# [21:51:36] Computing metrics
# [21:51:37] Saving artifacts
# [21:51:37] Saved model to /home/dhani/AnomalyIDS/dual-stage-ae/artifacts/rf_importance/model.pt
# [21:51:37] Saved scaler to /home/dhani/AnomalyIDS/dual-stage-ae/artifacts/rf_importance/scaler.pkl
# [21:51:37] Finished method: RF Importance
# [21:51:37] Selecting features: RFE
# [21:51:37] RFE subset shape: (10000, 42)
# [21:51:38] RFE selected: ['Dst Port', 'Flow Duration', 'Fwd Pkt Len Mean', 'Flow IAT Mean', 'Flow IAT Max', 'Bwd IAT Std', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Init Fwd Win Byts', 'Init Bwd Win Byts']
# [21:51:38] RFE selected features: ['Dst Port', 'Flow Duration', 'Fwd Pkt Len Mean', 'Flow IAT Mean', 'Flow IAT Max', 'Bwd IAT Std', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Init Fwd Win Byts', 'Init Bwd Win Byts']
#
# [21:51:38] >>> Starting dual-stage pipeline for: RFE
# [21:51:38] Preprocessing 80/20 benign split to /tmp/dual_stage_ae/rfe_fgeubbl_
# [21:51:38] Preprocessing file: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# [21:51:38] Counting valid benign rows: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# [21:51:42] Valid benign rows in Friday-02-03-2018_TrafficForML_CICFlowMeter.csv: 762384
# [21:51:51] Done Friday-02-03-2018_TrafficForML_CICFlowMeter.csv: train_benign=609907, test_benign=152477, attack_test=286191
# [21:51:51] Preprocessing file: Friday-16-02-2018_TrafficForML_CICFlowMeter.csv
# [21:51:51] Counting valid benign rows: Friday-16-02-2018_TrafficForML_CICFlowMeter.csv
# [21:51:55] Valid benign rows in Friday-16-02-2018_TrafficForML_CICFlowMeter.csv: 446772
# [21:52:03] Done Friday-16-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=357417, test_benign=89355, attack_test=601802
# [21:52:03] Preprocessing file: Friday-23-02-2018_TrafficForML_CICFlowMeter.csv
# [21:52:03] Counting valid benign rows: Friday-23-02-2018_TrafficForML_CICFlowMeter.csv
# [21:52:08] Valid benign rows in Friday-23-02-2018_TrafficForML_CICFlowMeter.csv: 1048009
# [21:52:16] Done Friday-23-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=838407, test_benign=209602, attack_test=566
# [21:52:16] Preprocessing file: Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv
# [21:52:16] Counting valid benign rows: Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv
# [21:53:08] Valid benign rows in Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv: 7372557
# [21:54:30] Done Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=5898045, test_benign=1474512, attack_test=576191
# [21:54:30] Preprocessing file: Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv
# [21:54:30] Counting valid benign rows: Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv
# [21:54:32] Valid benign rows in Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv: 238037
# [21:54:36] Done Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv: train_benign=190429, test_benign=47608, attack_test=93063
# [21:54:36] Preprocessing file: Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv
# [21:54:36] Counting valid benign rows: Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv
# [21:54:40] Valid benign rows in Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv: 996077
# [21:54:50] Done Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=796861, test_benign=199216, attack_test=52498
# [21:54:50] Preprocessing file: Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv
# [21:54:50] Counting valid benign rows: Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv
# [21:54:54] Valid benign rows in Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv: 1048213
# [21:55:03] Done Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=838570, test_benign=209643, attack_test=362
# [21:55:03] Preprocessing file: Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv
# [21:55:03] Counting valid benign rows: Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv
# [21:55:08] Valid benign rows in Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv: 667626
# [21:55:17] Done Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=534100, test_benign=133526, attack_test=380949
# [21:55:17] Preprocessing file: Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv
# [21:55:17] Counting valid benign rows: Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv
# [21:55:20] Valid benign rows in Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv: 360833
# [21:55:28] Done Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=288666, test_benign=72167, attack_test=687742
# [21:55:28] Preprocessing file: Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv
# [21:55:28] Counting valid benign rows: Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv
# [21:55:35] Valid benign rows in Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv: 544200
# [21:55:44] Done Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=435360, test_benign=108840, attack_test=68871
# [21:55:44] Split audit
#                                               file  total_valid_benign  train_benign  test_benign  attack_test  train_benign_ratio
#    Friday-02-03-2018_TrafficForML_CICFlowMeter.csv              762384        609907       152477       286191            0.800000
#    Friday-16-02-2018_TrafficForML_CICFlowMeter.csv              446772        357417        89355       601802            0.799999
#    Friday-23-02-2018_TrafficForML_CICFlowMeter.csv             1048009        838407       209602          566            0.800000
#  Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv             7372557       5898045      1474512       576191            0.800000
#  Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv              238037        190429        47608        93063            0.799997
#  Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv              996077        796861       199216        52498            0.799999
#  Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv             1048213        838570       209643          362            0.800000
# Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv              667626        534100       133526       380949            0.799999
# Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv              360833        288666        72167       687742            0.799999
# Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv              544200        435360       108840        68871            0.800000
# [21:55:44] Fitting streaming StandardScaler
# [21:55:44] Scaler file: train_Friday-02-03-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:44] Scaler file: train_Friday-16-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:44] Scaler file: train_Friday-23-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:44] Scaler file: train_Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:45] Scaler file: train_Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:45] Scaler file: train_Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:45] Scaler file: train_Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:46] Scaler file: train_Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:46] Scaler file: train_Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:46] Scaler file: train_Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [21:55:46] Scaler ready
# [21:55:46] Building dual-stage model
# [21:55:46] Training Stage 1 autoencoder
# [21:58:06] Stage 1 epoch 1/3 | loss=0.171727
# [22:00:27] Stage 1 epoch 2/3 | loss=0.130438
# [22:02:47] Stage 1 epoch 3/3 | loss=0.112806
# [22:02:47] Training Stage 2 residual autoencoder
# [22:05:46] Stage 2 epoch 1/3 | loss=0.075759
# [22:08:44] Stage 2 epoch 2/3 | loss=0.064137
# [22:11:44] Stage 2 epoch 3/3 | loss=0.060398
# [22:11:44] Scoring train sequences
# [22:11:44] Total sequences to score: 1078772
# [22:13:15] Scoring done
# [22:13:15] Train anomaly threshold (P95): 0.534507
# [22:13:15] Scoring test sequences
# [22:13:15] Total sequences to score: 544513
# [22:14:04] Scoring done
# [22:14:04] Computing metrics
# [22:14:05] Saving artifacts
# [22:14:05] Saved model to /home/dhani/AnomalyIDS/dual-stage-ae/artifacts/rfe/model.pt
# [22:14:05] Saved scaler to /home/dhani/AnomalyIDS/dual-stage-ae/artifacts/rfe/scaler.pkl
# [22:14:05] Finished method: RFE
# [22:14:05] Selecting features: mRMR
# [22:14:11] mRMR selected: ['Dst Port', 'Fwd Header Len', 'Bwd Pkts/b Avg', 'Init Fwd Win Byts', 'Flow IAT Mean', 'Bwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/s', 'Subflow Fwd Byts', 'Fwd Byts/b Avg']
# [22:14:11] mRMR selected features: ['Dst Port', 'Fwd Header Len', 'Bwd Pkts/b Avg', 'Init Fwd Win Byts', 'Flow IAT Mean', 'Bwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/s', 'Subflow Fwd Byts', 'Fwd Byts/b Avg']
#
# [22:14:11] >>> Starting dual-stage pipeline for: mRMR
# [22:14:11] Preprocessing 80/20 benign split to /tmp/dual_stage_ae/mrmr_3xppf3lr
# [22:14:11] Preprocessing file: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# [22:14:11] Counting valid benign rows: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# [22:14:17] Valid benign rows in Friday-02-03-2018_TrafficForML_CICFlowMeter.csv: 762384
# [22:14:26] Done Friday-02-03-2018_TrafficForML_CICFlowMeter.csv: train_benign=609907, test_benign=152477, attack_test=286191
# [22:14:26] Preprocessing file: Friday-16-02-2018_TrafficForML_CICFlowMeter.csv
# [22:14:26] Counting valid benign rows: Friday-16-02-2018_TrafficForML_CICFlowMeter.csv
# [22:14:30] Valid benign rows in Friday-16-02-2018_TrafficForML_CICFlowMeter.csv: 446772
# [22:14:39] Done Friday-16-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=357417, test_benign=89355, attack_test=601802
# [22:14:39] Preprocessing file: Friday-23-02-2018_TrafficForML_CICFlowMeter.csv
# [22:14:39] Counting valid benign rows: Friday-23-02-2018_TrafficForML_CICFlowMeter.csv
# [22:14:43] Valid benign rows in Friday-23-02-2018_TrafficForML_CICFlowMeter.csv: 1048009
# [22:14:51] Done Friday-23-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=838407, test_benign=209602, attack_test=566
# [22:14:51] Preprocessing file: Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv
# [22:14:51] Counting valid benign rows: Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv
# [22:15:29] Valid benign rows in Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv: 7372557
# [22:16:48] Done Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=5898045, test_benign=1474512, attack_test=576191
# [22:16:48] Preprocessing file: Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv
# [22:16:48] Counting valid benign rows: Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv
# [22:16:50] Valid benign rows in Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv: 238037
# [22:16:53] Done Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv: train_benign=190429, test_benign=47608, attack_test=93063
# [22:16:53] Preprocessing file: Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv
# [22:16:53] Counting valid benign rows: Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv
# [22:16:58] Valid benign rows in Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv: 996077
# [22:17:06] Done Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=796861, test_benign=199216, attack_test=52498
# [22:17:06] Preprocessing file: Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv
# [22:17:06] Counting valid benign rows: Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv
# [22:17:10] Valid benign rows in Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv: 1048213
# [22:17:18] Done Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=838570, test_benign=209643, attack_test=362
# [22:17:18] Preprocessing file: Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv
# [22:17:18] Counting valid benign rows: Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv
# [22:17:22] Valid benign rows in Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv: 667626
# [22:17:30] Done Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=534100, test_benign=133526, attack_test=380949
# [22:17:30] Preprocessing file: Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv
# [22:17:30] Counting valid benign rows: Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv
# [22:17:34] Valid benign rows in Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv: 360833
# [22:17:41] Done Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=288666, test_benign=72167, attack_test=687742
# [22:17:42] Preprocessing file: Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv
# [22:17:42] Counting valid benign rows: Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv
# [22:17:48] Valid benign rows in Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv: 544200
# [22:17:56] Done Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv: train_benign=435360, test_benign=108840, attack_test=68871
# [22:17:56] Split audit
#                                               file  total_valid_benign  train_benign  test_benign  attack_test  train_benign_ratio
#    Friday-02-03-2018_TrafficForML_CICFlowMeter.csv              762384        609907       152477       286191            0.800000
#    Friday-16-02-2018_TrafficForML_CICFlowMeter.csv              446772        357417        89355       601802            0.799999
#    Friday-23-02-2018_TrafficForML_CICFlowMeter.csv             1048009        838407       209602          566            0.800000
#  Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv             7372557       5898045      1474512       576191            0.800000
#  Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv              238037        190429        47608        93063            0.799997
#  Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv              996077        796861       199216        52498            0.799999
#  Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv             1048213        838570       209643          362            0.800000
# Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv              667626        534100       133526       380949            0.799999
# Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv              360833        288666        72167       687742            0.799999
# Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv              544200        435360       108840        68871            0.800000
# [22:17:56] Fitting streaming StandardScaler
# [22:17:56] Scaler file: train_Friday-02-03-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:56] Scaler file: train_Friday-16-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:56] Scaler file: train_Friday-23-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:57] Scaler file: train_Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:58] Scaler file: train_Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:58] Scaler file: train_Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:58] Scaler file: train_Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:58] Scaler file: train_Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:58] Scaler file: train_Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:58] Scaler file: train_Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv.parquet
# [22:17:58] Scaler ready
# [22:17:58] Building dual-stage model
# [22:17:58] Training Stage 1 autoencoder
# [22:20:17] Stage 1 epoch 1/3 | loss=0.069781
# [22:22:36] Stage 1 epoch 2/3 | loss=0.049154
# [22:24:56] Stage 1 epoch 3/3 | loss=0.040515
# [22:24:56] Training Stage 2 residual autoencoder
# [22:27:56] Stage 2 epoch 1/3 | loss=0.025515
# [22:30:56] Stage 2 epoch 2/3 | loss=0.021352
# [22:33:58] Stage 2 epoch 3/3 | loss=0.019783
# [22:33:58] Scoring train sequences
# [22:33:58] Total sequences to score: 1078772
# [22:35:31] Scoring done
# [22:35:31] Train anomaly threshold (P95): 0.169905
# [22:35:31] Scoring test sequences
# [22:35:31] Total sequences to score: 544513
# [22:36:22] Scoring done
# [22:36:22] Computing metrics
# [22:36:22] Saving artifacts
# [22:36:22] Saved model to /home/dhani/AnomalyIDS/dual-stage-ae/artifacts/mrmr/model.pt
# [22:36:22] Saved scaler to /home/dhani/AnomalyIDS/dual-stage-ae/artifacts/mrmr/scaler.pkl
# [22:36:23] Finished method: mRMR
#
# [22:36:23] === FINAL DUAL-STAGE COMPARISON ===
#                                                     Selected Features  \
# Mutual Information  Pkt Len Mean, Fwd Seg Size Min, Flow IAT Max, ...
# RF Importance       Flow Byts/s, Init Bwd Win Byts, Flow IAT Mean,...
# RFE                 Dst Port, Flow Duration, Fwd Pkt Len Mean, Flo...
# mRMR                Dst Port, Fwd Header Len, Bwd Pkts/b Avg, Init...
#
#                     Accuracy Precision    Recall        F1   ROC-AUC    PR-AUC
# Mutual Information  0.570602  0.949501  0.222934  0.361088   0.76391  0.812271
# RF Importance       0.557921  0.881729  0.219888  0.351994  0.715833  0.788195
# RFE                 0.553728  0.887975  0.206073  0.334515  0.647216  0.744773
# mRMR                0.613253   0.88011  0.335085  0.485373  0.658158  0.756103
